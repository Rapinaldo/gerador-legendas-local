# %%
# 1. Instala as dependências do Linux e do Python na máquina virtual do Google
# !apt-get install -y ffmpeg
# !pip install openai-whisper gradio

# 2. Baixa o script atualizado direto do seu repositório no GitHub
# !wget -O app_colab.py https://raw.githubusercontent.com/Rapinaldo/gerador-legendas-local/main/app_colab.py

# 3. Executa o aplicativo na nuvem
# !python app_colab.py
